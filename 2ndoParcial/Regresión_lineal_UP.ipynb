# %% [markdown]
# # Aprendizaje supervizado

# %% [markdown]
# Data
# https://drive.google.com/file/d/1U6yg04oZwO-Kltt_-VrFuiWB7a104rhH/view?usp=drive_link

# %% [markdown]
# ## Modelo de Regresión lineal
#
# Un **modelo de regresión lineal** es una ⚙ **función** ⚙ capaz de relacionar ejemplos del mismo tipo de objetos y predecir su comportamiento a través de una variable.
#
# En un modelo de regresión, la 🌟 **variable dependiente**, también conocida como variable de respuesta, es aquella que se intenta **predecir** o explicar.
#
# Las  🎢 **variables independientes**, también llamadas predictores o variables explicativas, son aquellas que se utilizan para predecir la variable dependiente.

# %% [markdown]
# La ecuación general de la regresión lineal simple se expresa como:
#
#  $Y = \beta_0 + \beta_1 X + \epsilon $
#
# Donde:
# - \( $Y$ \) es la variable dependiente.
# - \( $X$ \) es la variable independiente.
# - \( $\beta_0$ \) es el término de intersección o constante.
# - \( $\beta_1$ \) es el coeficiente de regresión que representa la pendiente de la línea.
# - \( $\epsilon$ \) es el error aleatorio.

# %% [markdown]
#  **Pista**: Una regresión lineal nos ayuda cuando debemos **predecir** un valor real

# %% [markdown]
# # Vamos a jugar con los datos

# %%
#Librerias
import pandas as pd

# %%
#Lectura de un archivo csv
data = pd.read_csv("kc_house_data.csv")

# %%
#Vemos que columnas existen
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
#Seleccionamos solo 2 columnas para nuestro analisis
data = data[["sqft_living", "price"]]

# %%
#Seleccionamos solo 50 datos
data = data.head(50)

# %%
data.head(5)
# Out:
#    sqft_living     price
# 0         1180  221900.0
# 1         2570  538000.0
# 2          770  180000.0
# 3         1960  604000.0
# 4         1680  510000.0

# %% [markdown]
# #### Notación de nuestros datos:
#
# *   m = Numero de observaciones
# *   $x_i$ = Features (variables independiente)
# *   $y$ =  Variable objetivo

# %%
import matplotlib.pyplot as plt

plt.scatter(data['sqft_living'], data['price'], color='blue', label='Datos')

plt.xlabel('Sqft')
plt.ylabel('Price')
plt.title('Relación entre Pies Cuadrados y Precio de la Casa')

# Agregar una leyenda
plt.legend()

# Mostrar el gráfico
plt.grid(True)
plt.show()

# %% [markdown]
# #### La hipotesis
# Es una función que toma como entrada un valor x y regrea una predicción
#
# $x_i$ -> $h(x_i)$ -> $Y_i$

# %%
import matplotlib.pyplot as plt

m = 0
b = 1

x = range(-10, 11)

y = [m * xi + b for xi in x]

plt.plot(x, y)

# Add labels and title
plt.xlabel('x')
plt.ylabel('y')



# Display the plot
plt.grid(True)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X_train, X_test, y_train, y_test = train_test_split(data[['sqft_living']], data['price'], test_size=0.2, random_state=42)


model = LinearRegression()

# Entrenar el modelo
model.fit(X_train, y_train)

# Coeficientes del modelo
print('Coeficiente:', model.coef_)
print('Intercepción:', model.intercept_)

# Predecir los valores para el conjunto de prueba
y_pred = model.predict(X_test)

# Graficar los datos de entrenamiento y la línea de regresión
plt.scatter(X_train, y_train, color='blue', label='Datos de Entrenamiento')
plt.scatter(X_test, y_test, color='red', label='Datos de Prueba')
plt.plot(X_test, y_pred, color='green', linewidth=3, label='Línea de Regresión')
plt.xlabel('Metros Cuadrados')
plt.ylabel('Precio')
plt.title('Regresión Lineal Simple')
plt.legend()
plt.grid(True)
# Out:
# Coeficiente: [240.81565795]
# Intercepción: 49756.034494264284
