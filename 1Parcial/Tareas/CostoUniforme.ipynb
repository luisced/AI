# %%
# Importamos las librerías para trabajar con BFS(Breadth-First Search)
# Búsqueda en amplitud

import networkx as nx
import heapq

import matplotlib.pyplot as plt
from collections import deque

# %%
grafo = {
    "A":{"B":3,"G":9,"S":5},
    "B":{"A":3,"C":1,"S":9,"X":7},
    "C":{"B":1,"D":2,"I":5},
    "D":{"C":2,"E":2,"F":2,"S":6},
    "E":{"D":2,"X":3},
    "F":{"D":2,"G":3},
    "G":{"A":9},
    "I":{"C":5,"J":6,"X":3},
    "S":{"A":5,"B":9,"D":6},

    "X":{"B":7,"E":3,"I":3},
}

# %%
# Crear un grafo de NetworkX y agregar nodos y aristas
G = nx.Graph()
for nodo, vecinos in grafo.items():
    for vecino, peso in vecinos.items():
        G.add_edge(nodo, vecino, weight=peso)

# %%
# Dibujar el grafo
pos = nx.spring_layout(G) # Creamos la red de nodos
labels = nx.get_edge_attributes(G, 'weight') # Asignamos los pesos (valores) que se verán en la red
nx.draw(G, pos, with_labels=True, node_size=700, node_color='skyblue', font_size=12, font_weight='bold')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
plt.title('Grafo de ejemplo')
plt.show()

# %%
# Algoritmo de costo uniforme
def costo_uniforme(inicio, objetivo, grafo):
    cola_prioridad = []
    heapq.heappush(cola_prioridad, (0, inicio, [inicio]))  # Un heap es una estructura de datos 
                                                           # basada en un árbol binario
                                                           # heapq.heappush(heap, item): 
                                                           # Agrega un nuevo elemento al montón.
    visitados = set()
    
    while cola_prioridad:
        costo_actual, nodo_actual, camino = heapq.heappop(cola_prioridad)
                                                           # heapq.heappop(heap):
                                                           # Elimina y devuelve el
                                                           # elemento más pequeño del montón.
        print("--------------------")
        print("Nodos visitados", visitados)
        print("Nodo Actual:", nodo_actual)
        print("Costo Actual:", costo_actual)
        print("Camino:", camino)
        
        if nodo_actual == objetivo:
            return costo_actual, camino
        
        if nodo_actual not in visitados:
            visitados.add(nodo_actual)
            for vecino, costo in grafo[nodo_actual].items():
                if vecino not in visitados: # Visitamos solo los vecinos NO visitados
                    nuevo_costo = costo_actual + costo
                    nuevo_camino = camino + [vecino]
                    heapq.heappush(cola_prioridad, (nuevo_costo, vecino, nuevo_camino))
            print("Cola:", cola_prioridad)

    return float('inf'), []

# %%
# Calcular el costo mínimo y el camino usando búsqueda de costo uniforme
inicio = 'S'
objetivo = 'X'
costo_minimo, camino_minimo = costo_uniforme(inicio, objetivo, grafo)

# Imprimir el costo mínimo y el camino
if costo_minimo != float('inf'):
    print(f"El costo mínimo desde {inicio} hasta {objetivo} es: {costo_minimo}")
    print(f"El camino mínimo es: {' -> '.join(camino_minimo)}")
else:
    print(f"No se encontró un camino desde {inicio} hasta {objetivo}")
# Out:
# --------------------
# Nodos visitados set()
# Nodo Actual: S
# Costo Actual: 0
# Camino: ['S']
# Cola: [(5, 'A', ['S', 'A']), (9, 'B', ['S', 'B']), (6, 'D', ['S', 'D'])]
# --------------------
# Nodos visitados {'S'}
# Nodo Actual: A
# Costo Actual: 5
# Camino: ['S', 'A']
# Cola: [(6, 'D', ['S', 'D']), (9, 'B', ['S', 'B']), (8, 'B', ['S', 'A', 'B']), (14, 'G', ['S', 'A', 'G'])]
# --------------------
# Nodos visitados {'S', 'A'}
# Nodo Actual: D
# Costo Actual: 6
# Camino: ['S', 'D']
# Cola: [(8, 'B', ['S', 'A', 'B']), (8, 'C', ['S', 'D', 'C']), (8, 'F', ['S', 'D', 'F']), (9, 'B', ['S', 'B']), (8, 'E', ['S', 'D', 'E']), (14, 'G', ['S', 'A', 'G'])]
# --------------------
# Nodos visitados {'D', 'S', 'A'}
# Nodo Actual: B
# Costo Actual: 8
# Camino: ['S', 'A', 'B']
# Cola: [(8, 'C', ['S', 'D', 'C']), (8, 'E', ['S', 'D', 'E']), (8, 'F', ['S', 'D', 'F']), (9, 'B', ['S', 'B']), (14, 'G', ['S', 'A', 'G']), (9, 'C', ['S', 'A', 'B', 'C']), (15, 'X', ['S', 'A', 'B', 'X'])]
# --------------------
# Nodos visitados {'D', 'S', 'A', 'B'}
# Nodo Actual: C
# Costo Actual: 8
# Camino: ['S', 'D', 'C']
# Cola: [(8, 'E', ['S', 'D', 'E']), (9, 'B', ['S', 'B']), (8, 'F', ['S', 'D', 'F']), (15, 'X', ['S', 'A', 'B', 'X']), (14, 'G', ['S', 'A', 'G']), (9, 'C', ['S', 'A', 'B', 'C']), (13, 'I', ['S', 'D', 'C', 'I'])]
# --------------------
# Nodos visitados {'B', 'A', 'D', 'S', 'C'}
# Nodo Actual: E
# Costo Actual: 8
# Camino: ['S', 'D', 'E']
# Cola: [(8, 'F', ['S', 'D', 'F']), (9, 'B', ['S', 'B']), (9, 'C', ['S', 'A', 'B', 'C']), (15, 'X', ['S', 'A', 'B', 'X']), (14, 'G', ['S', 'A', 'G']), (13, 'I', ['S', 'D', 'C', 'I']), (11, 'X', ['S', 'D', 'E', 'X'])]
# --------------------
# Nodos visitados {'B', 'E', 'A', 'D', 'S', 'C'}
# Nodo Actual: F
# Costo Actual: 8
# Camino: ['S', 'D', 'F']
# Cola: [(9, 'B', ['S', 'B']), (11, 'X', ['S', 'D', 'E', 'X']), (9, 'C', ['S', 'A', 'B', 'C']), (15, 'X', ['S', 'A', 'B', 'X']), (14, 'G', ['S', 'A', 'G']), (13, 'I', ['S', 'D', 'C', 'I']), (11, 'G', ['S', 'D', 'F', 'G'])]
# --------------------
# Nodos visitados {'B', 'E', 'F', 'A', 'D', 'S', 'C'}
# Nodo Actual: B
# Costo Actual: 9
# Camino: ['S', 'B']
# --------------------
# Nodos visitados {'B', 'E', 'F', 'A', 'D', 'S', 'C'}
# Nodo Actual: C
# Costo Actual: 9
# Camino: ['S', 'A', 'B', 'C']
# --------------------
# Nodos visitados {'B', 'E', 'F', 'A', 'D', 'S', 'C'}
# Nodo Actual: G
# Costo Actual: 11
# Camino: ['S', 'D', 'F', 'G']
# Cola: [(11, 'X', ['S', 'D', 'E', 'X']), (14, 'G', ['S', 'A', 'G']), (13, 'I', ['S', 'D', 'C', 'I']), (15, 'X', ['S', 'A', 'B', 'X'])]
# --------------------
# Nodos visitados {'B', 'E', 'G', 'F', 'A', 'D', 'S', 'C'}
# Nodo Actual: X
# Costo Actual: 11
# Camino: ['S', 'D', 'E', 'X']
# El costo mínimo desde S hasta X es: 11
# El camino mínimo es: S -> D -> E -> X
