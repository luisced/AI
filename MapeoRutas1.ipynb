# %%
# Importamos las librerías para trabajar con DFS(Depth-First Search)
# Búsqueda en profundidad

import networkx as nx
import matplotlib.pyplot as plt
from collections import deque

# %%
def dfs(grafo, inicio, objetivo, visitados=None, camino=None, caminos_encontrados=None, i=0):
    i += 1
    print("\nNivel de profundidad:", i)
    
    # Si entramos a este método por primera vez
    if visitados is None:
        visitados = set()
    if camino is None:
        camino = []
    if caminos_encontrados is None:
        caminos_encontrados = []

    camino.append(inicio)
    visitados.add(inicio)

    print("Nodo actual:", inicio)
    print("Nodos visitados", visitados)
    print("Camino Actual:", camino)

    if inicio == objetivo:
        print("Camino encontrado:", ' -> '.join(camino))
        caminos_encontrados.append(camino.copy())
    else:
        for vecino in grafo[inicio]:
            if vecino not in visitados:
                dfs(grafo, vecino, objetivo, visitados, camino, caminos_encontrados, i)

    camino.pop()  # Eliminamos el último nodo para retroceder al nodo anterior
    visitados.remove(inicio)

    return caminos_encontrados

# %%
# Definimos el grafo como un diccionario de listas de adyacencia
grafo = {
    'A': ['B', 'D'],
    'B': ['A', 'C', 'E'],
    'C':['B','C'],
    'D':['A', 'E','G'],
    'E':['B','D', 'F','H'],
    'F':['C', 'E','I'],
    'G':['D','H'],
    'H':['E','G','I'],
    'I':['F','H']
    
}

# Nodo de inicio y nodo objetivo
nodo_inicio = 'A'
nodo_objetivo = 'I'

print("Recorrido DFS:")
caminos_encontrados = dfs(grafo, nodo_inicio, nodo_objetivo)

if caminos_encontrados:
    print("Caminos encontrados:")
    for camino in caminos_encontrados:
        print(' -> '.join(camino))
else:
    print("No se encontró un camino al nodo objetivo.")
# Out:
# Recorrido DFS:
#
# Nivel de profundidad: 1
# Nodo actual: A
# Nodos visitados {'A'}
# Camino Actual: ['A']
#
# Nivel de profundidad: 2
# Nodo actual: B
# Nodos visitados {'A', 'B'}
# Camino Actual: ['A', 'B']
#
# Nivel de profundidad: 3
# Nodo actual: C
# Nodos visitados {'A', 'B', 'C'}
# Camino Actual: ['A', 'B', 'C']
#
# Nivel de profundidad: 3
# Nodo actual: E
# Nodos visitados {'A', 'E', 'B'}
# Camino Actual: ['A', 'B', 'E']
#
# Nivel de profundidad: 4
# Nodo actual: D
# Nodos visitados {'B', 'E', 'A', 'D'}
# Camino Actual: ['A', 'B', 'E', 'D']
#
# Nivel de profundidad: 5
# Nodo actual: G
# Nodos visitados {'B', 'E', 'G', 'A', 'D'}
# Camino Actual: ['A', 'B', 'E', 'D', 'G']
#
# Nivel de profundidad: 6
# Nodo actual: H
# Nodos visitados {'H', 'B', 'E', 'G', 'A', 'D'}
# Camino Actual: ['A', 'B', 'E', 'D', 'G', 'H']
#
# Nivel de profundidad: 7
# Nodo actual: I
# Nodos visitados {'H', 'B', 'E', 'I', 'G', 'A', 'D'}
# Camino Actual: ['A', 'B', 'E', 'D', 'G', 'H', 'I']
# Camino encontrado: A -> B -> E -> D -> G -> H -> I
#
# Nivel de profundidad: 4
# Nodo actual: F
# Nodos visitados {'B', 'E', 'F', 'A'}
# Camino Actual: ['A', 'B', 'E', 'F']
#
# Nivel de profundidad: 5
# Nodo actual: C
# Nodos visitados {'B', 'E', 'C', 'F', 'A'}
# Camino Actual: ['A', 'B', 'E', 'F', 'C']
#
# Nivel de profundidad: 5
# Nodo actual: I
# Nodos visitados {'B', 'E', 'I', 'F', 'A'}
# Camino Actual: ['A', 'B', 'E', 'F', 'I']
# Camino encontrado: A -> B -> E -> F -> I
#
# Nivel de profundidad: 4
# Nodo actual: H
# Nodos visitados {'H', 'B', 'E', 'A'}
# Camino Actual: ['A', 'B', 'E', 'H']
#
# Nivel de profundidad: 5
# Nodo actual: G
# Nodos visitados {'H', 'B', 'E', 'G', 'A'}
# Camino Actual: ['A', 'B', 'E', 'H', 'G']
#
# Nivel de profundidad: 6
# Nodo actual: D
# Nodos visitados {'H', 'B', 'E', 'G', 'A', 'D'}
# Camino Actual: ['A', 'B', 'E', 'H', 'G', 'D']
#
# Nivel de profundidad: 5
# Nodo actual: I
# Nodos visitados {'H', 'B', 'E', 'I', 'A'}
# Camino Actual: ['A', 'B', 'E', 'H', 'I']
# Camino encontrado: A -> B -> E -> H -> I
#
# Nivel de profundidad: 2
# Nodo actual: D
# Nodos visitados {'A', 'D'}
# Camino Actual: ['A', 'D']
#
# Nivel de profundidad: 3
# Nodo actual: E
# Nodos visitados {'E', 'A', 'D'}
# Camino Actual: ['A', 'D', 'E']
#
# Nivel de profundidad: 4
# Nodo actual: B
# Nodos visitados {'B', 'E', 'A', 'D'}
# Camino Actual: ['A', 'D', 'E', 'B']
#
# Nivel de profundidad: 5
# Nodo actual: C
# Nodos visitados {'B', 'E', 'C', 'A', 'D'}
# Camino Actual: ['A', 'D', 'E', 'B', 'C']
#
# Nivel de profundidad: 4
# Nodo actual: F
# Nodos visitados {'E', 'F', 'A', 'D'}
# Camino Actual: ['A', 'D', 'E', 'F']
#
# Nivel de profundidad: 5
# Nodo actual: C
# Nodos visitados {'E', 'C', 'F', 'A', 'D'}
# Camino Actual: ['A', 'D', 'E', 'F', 'C']
#
# Nivel de profundidad: 6
# Nodo actual: B
# Nodos visitados {'B', 'E', 'C', 'F', 'A', 'D'}
# Camino Actual: ['A', 'D', 'E', 'F', 'C', 'B']
#
# Nivel de profundidad: 5
# Nodo actual: I
# Nodos visitados {'E', 'I', 'F', 'A', 'D'}
# Camino Actual: ['A', 'D', 'E', 'F', 'I']
# Camino encontrado: A -> D -> E -> F -> I
#
# Nivel de profundidad: 4
# Nodo actual: H
# Nodos visitados {'H', 'E', 'A', 'D'}
# Camino Actual: ['A', 'D', 'E', 'H']
#
# Nivel de profundidad: 5
# Nodo actual: G
# Nodos visitados {'H', 'E', 'G', 'A', 'D'}
# Camino Actual: ['A', 'D', 'E', 'H', 'G']
#
# Nivel de profundidad: 5
# Nodo actual: I
# Nodos visitados {'H', 'E', 'I', 'A', 'D'}
# Camino Actual: ['A', 'D', 'E', 'H', 'I']
# Camino encontrado: A -> D -> E -> H -> I
#
# Nivel de profundidad: 3
# Nodo actual: G
# Nodos visitados {'G', 'A', 'D'}
# Camino Actual: ['A', 'D', 'G']
#
# Nivel de profundidad: 4
# Nodo actual: H
# Nodos visitados {'H', 'G', 'A', 'D'}
# Camino Actual: ['A', 'D', 'G', 'H']
#
# Nivel de profundidad: 5
# Nodo actual: E
# Nodos visitados {'H', 'E', 'G', 'A', 'D'}
# Camino Actual: ['A', 'D', 'G', 'H', 'E']
#
# Nivel de profundidad: 6
# Nodo actual: B
# Nodos visitados {'H', 'B', 'E', 'G', 'A', 'D'}
# Camino Actual: ['A', 'D', 'G', 'H', 'E', 'B']
#
# Nivel de profundidad: 7
# Nodo actual: C
# Nodos visitados {'H', 'B', 'E', 'G', 'C', 'A', 'D'}
# Camino Actual: ['A', 'D', 'G', 'H', 'E', 'B', 'C']
#
# Nivel de profundidad: 6
# Nodo actual: F
# Nodos visitados {'H', 'E', 'G', 'F', 'A', 'D'}
# Camino Actual: ['A', 'D', 'G', 'H', 'E', 'F']
#
# Nivel de profundidad: 7
# Nodo actual: C
# Nodos visitados {'H', 'E', 'G', 'C', 'F', 'A', 'D'}
# Camino Actual: ['A', 'D', 'G', 'H', 'E', 'F', 'C']
#
# Nivel de profundidad: 8
# Nodo actual: B
# Nodos visitados {'H', 'B', 'E', 'G', 'C', 'F', 'A', 'D'}
# Camino Actual: ['A', 'D', 'G', 'H', 'E', 'F', 'C', 'B']
#
# Nivel de profundidad: 7
# Nodo actual: I
# Nodos visitados {'H', 'E', 'I', 'G', 'F', 'A', 'D'}
# Camino Actual: ['A', 'D', 'G', 'H', 'E', 'F', 'I']
# Camino encontrado: A -> D -> G -> H -> E -> F -> I
#
# Nivel de profundidad: 5
# Nodo actual: I
# Nodos visitados {'H', 'I', 'G', 'A', 'D'}
# Camino Actual: ['A', 'D', 'G', 'H', 'I']
# Camino encontrado: A -> D -> G -> H -> I
# Caminos encontrados:
# A -> B -> E -> D -> G -> H -> I
# A -> B -> E -> F -> I
# A -> B -> E -> H -> I
# A -> D -> E -> F -> I
# A -> D -> E -> H -> I
# A -> D -> G -> H -> E -> F -> I
# A -> D -> G -> H -> I

# %%
# Definimos nuestro algoritmo de búsqueda:

def busqueda_amplitud(grafo, inicio, objetivo):
    # El método set crea un conjunto de datos SIMILAR a una lista pero que
    # NO puede tener elementos duplicados
    visitados = set()
    # (Doubly Ended Queue) Es un tio de lista que permite agregar y eliminar
    # elementos ya sea a la izquiera o a la derecha de la misma
    cola = deque([(inicio, [inicio])])

    i = 1
    while cola:
        # Aquí removemos el primer elemento del set (El de la izquierda)
        # y este será nuestro nodo actual, el resto, el camino (Path restante)
        nodo_actual, camino = cola.popleft()
        print("\nIteración:", i)
        print("Nodo actual:", nodo_actual)
        
        if nodo_actual == objetivo:
            print("Camino encontrado:", "->".join(camino))
            return camino
        
        if nodo_actual not in visitados:
            visitados.add(nodo_actual)
            print("Nodos visitados", visitados)
            for vecino in grafo[nodo_actual]:
                if vecino not in visitados:
                    nueva_ruta = camino + [vecino]
                    print("Nueva ruta:", nueva_ruta)
                    cola.append((vecino, nueva_ruta))
        i += 1
    print("No se encontró un camino al nodo objetivo.")
    return None

caminos_encontrados = busqueda_amplitud(grafo, nodo_inicio, nodo_objetivo)
print("Caminos encontrados:", caminos_encontrados)
